# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from sklearn.utils import parallel_backend
import optuna
from imblearn.under_sampling import ClusterCentroids
from warnings import filterwarnings
filterwarnings('ignore')

# %%
ad = pd.read_csv("heart_attack_russia_youth_vs_adult.csv")
df = ad.copy()
df.head(5)
# Out:
#    ID  Age  Gender Region  Blood_Pressure  Cholesterol   BMI  Heart_Rate  \
# 0   1   50    Male  Rural           110.0        196.5  15.9          76
# 1   2   40  Female  Urban           138.8        157.5  27.1          82
# 2   3   26    Male  Rural           116.0        210.1  27.2          71
# 3   4   54  Female  Rural           133.5        170.5  26.0          74
# 4   5   19  Female  Urban           108.0        224.5  27.5          67
#
#   Exercise_Level  Smoking  ... Income_Level  Physical_Activity  \
# 0           High    False  ...          Low                Low
# 1       Moderate    False  ...          Low           Moderate
# 2       Moderate    False  ...       Middle               High
# 3       Moderate     True  ...       Middle           Moderate
# 4            Low    False  ...       Middle                Low
#
#    Education_Level  Marital_Status  Urban_Rural  Medication  Health_Awareness  \
# 0          Primary         Married        Rural       False                 5
# 1           Higher         Married        Urban       False                 1
# 2          Primary         Married        Urban       False                 4
# 3           Higher         Married        Urban       False                 2
# 4           Higher         Widowed        Urban       False                 4
#
#   Daily_Water_Intake  Mental_Health Obesity
# 0                2.3              5   False
# 1                5.0              4   False
# 2                2.4              8   False
# 3                2.7              6    True
# 4                3.5              4    True
#
# [5 rows x 30 columns]

# %%
df.describe().T
# Out:
#                       count          mean           std   min       25%  \
# ID                  50000.0  25000.500000  14433.901067   1.0  12500.75
# Age                 50000.0     35.991820     14.110139  12.0     24.00
# Blood_Pressure      50000.0    120.058636     14.975835  60.0    109.90
# Cholesterol         50000.0    199.852762     49.998331 -18.7    166.10
# BMI                 50000.0     24.983912      5.003784   2.9     21.60
# Heart_Rate          50000.0     79.988980     11.804567  60.0     70.00
# Stress_Level        50000.0      5.503700      2.870741   1.0      3.00
# Sleep_Hours         50000.0      7.011464      1.740651   4.0      5.50
# Health_Awareness    50000.0      3.007100      1.410351   1.0      2.00
# Daily_Water_Intake  50000.0      2.997782      1.149608   1.0      2.00
# Mental_Health       50000.0      5.486740      2.860760   1.0      3.00
#
#                          50%       75%      max
# ID                  25000.50  37500.25  50000.0
# Age                    36.00     48.00     60.0
# Blood_Pressure        120.05    130.20    188.4
# Cholesterol           199.90    233.50    398.8
# BMI                    25.00     28.40     46.1
# Heart_Rate             80.00     90.00    100.0
# Stress_Level            6.00      8.00     10.0
# Sleep_Hours             7.00      8.50     10.0
# Health_Awareness        3.00      4.00      5.0
# Daily_Water_Intake      3.00      4.00      5.0
# Mental_Health           5.00      8.00     10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Region                 50000 non-null  object
#  4   Blood_Pressure         50000 non-null  float64
#  5   Cholesterol            50000 non-null  float64
#  6   BMI                    50000 non-null  float64
#  7   Heart_Rate             50000 non-null  int64
#  8   Exercise_Level         50000 non-null  object
#  9   Smoking                50000 non-null  bool
#  10  Alcohol_Consumption    24976 non-null  object
#  11  Diabetes               50000 non-null  bool
#  12  Family_History         50000 non-null  bool
#  13  Stress_Level           50000 non-null  int64
#  14  Heart_Attack           50000 non-null  bool
#  15  Angina                 50000 non-null  bool
#  16  Heart_Disease_History  50000 non-null  bool
#  17  Diet                   50000 non-null  object
#  18  Sleep_Hours            50000 non-null  float64
#  19  Occupation             50000 non-null  object
#  20  Income_Level           50000 non-null  object
#  21  Physical_Activity      50000 non-null  object
#  22  Education_Level        50000 non-null  object
#  23  Marital_Status         50000 non-null  object
#  24  Urban_Rural            50000 non-null  object
#  25  Medication             50000 non-null  bool
#  26  Health_Awareness       50000 non-null  int64
#  27  Daily_Water_Intake     50000 non-null  float64
#  28  Mental_Health          50000 non-null  int64
#  29  Obesity                50000 non-null  bool
# dtypes: bool(8), float64(5), int64(6), object(11)
# memory usage: 8.8+ MB

# %%
for i in df.select_dtypes(include='object').columns:
    print(df[i].value_counts())
    print('****'*20)
# Out:
# Gender
# Female    24155
# Male      23944
# Other      1901
# Name: count, dtype: int64
# ********************************************************************************
# Region
# Urban       25034
# Rural       14946
# Suburban    10020
# Name: count, dtype: int64
# ********************************************************************************
# Exercise_Level
# Moderate    24946
# Low         15100
# High         9954
# Name: count, dtype: int64
# ********************************************************************************
# Alcohol_Consumption
# Moderate    20022
# Heavy        4954
# Name: count, dtype: int64
# ********************************************************************************
# Diet
# Healthy      19789
# Mixed        15185
# Unhealthy    15026
# Name: count, dtype: int64
# ********************************************************************************
# Occupation
# Employed      25166
# Student       10068
# Unemployed     9843
# Retired        4923
# Name: count, dtype: int64
# ********************************************************************************
# Income_Level
# Middle    20025
# Low       19863
# High      10112
# Name: count, dtype: int64
# ********************************************************************************
# Physical_Activity
# Moderate    24828
# Low         15158
# High        10014
# Name: count, dtype: int64
# ********************************************************************************
# Education_Level
# Secondary    20064
# Primary      14983
# Higher       14953
# Name: count, dtype: int64
# ********************************************************************************
# Marital_Status
# Married     25099
# Single      19975
# Divorced     2476
# Widowed      2450
# Name: count, dtype: int64
# ********************************************************************************
# Urban_Rural
# Urban    30142
# Rural    19858
# Name: count, dtype: int64
# ********************************************************************************

# %%
df = pd.get_dummies(df, columns=['Gender'])

# %%
df=df.drop(["Gender_Other"],axis=1)

# %%
df = pd.get_dummies(df, columns=['Region'])

# %%
df = pd.get_dummies(df, columns=['Exercise_Level'])

# %%
df=df.drop(["Alcohol_Consumption"],axis=1)

# %%
df = pd.get_dummies(df, columns=['Diet'])

# %%
df = pd.get_dummies(df, columns=['Occupation'])

# %%
df = pd.get_dummies(df, columns=['Income_Level'])

# %%
df = pd.get_dummies(df, columns=['Physical_Activity'])

# %%
df = pd.get_dummies(df, columns=['Education_Level'])

# %%
df = pd.get_dummies(df, columns=['Marital_Status'])

# %%
df = pd.get_dummies(df, columns=['Urban_Rural'])

# %%
df=df.drop(["Urban_Rural_Urban"],axis=1)

# %%
df=df.drop(["ID"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         50000 non-null  int64
#  1   Blood_Pressure              50000 non-null  float64
#  2   Cholesterol                 50000 non-null  float64
#  3   BMI                         50000 non-null  float64
#  4   Heart_Rate                  50000 non-null  int64
#  5   Smoking                     50000 non-null  bool
#  6   Diabetes                    50000 non-null  bool
#  7   Family_History              50000 non-null  bool
#  8   Stress_Level                50000 non-null  int64
#  9   Heart_Attack                50000 non-null  bool
#  10  Angina                      50000 non-null  bool
#  11  Heart_Disease_History       50000 non-null  bool
#  12  Sleep_Hours                 50000 non-null  float64
#  13  Medication                  50000 non-null  bool
#  14  Health_Awareness            50000 non-null  int64
#  15  Daily_Water_Intake          50000 non-null  float64
#  16  Mental_Health               50000 non-null  int64
#  17  Obesity                     50000 non-null  bool
#  18  Gender_Female               50000 non-null  bool
#  19  Gender_Male                 50000 non-null  bool
#  20  Region_Rural                50000 non-null  bool
#  21  Region_Suburban             50000 non-null  bool
#  22  Region_Urban                50000 non-null  bool
#  23  Exercise_Level_High         50000 non-null  bool
#  24  Exercise_Level_Low          50000 non-null  bool
#  25  Exercise_Level_Moderate     50000 non-null  bool
#  26  Diet_Healthy                50000 non-null  bool
#  27  Diet_Mixed                  50000 non-null  bool
#  28  Diet_Unhealthy              50000 non-null  bool
#  29  Occupation_Employed         50000 non-null  bool
#  30  Occupation_Retired          50000 non-null  bool
#  31  Occupation_Student          50000 non-null  bool
#  32  Occupation_Unemployed       50000 non-null  bool
#  33  Income_Level_High           50000 non-null  bool
#  34  Income_Level_Low            50000 non-null  bool
#  35  Income_Level_Middle         50000 non-null  bool
#  36  Physical_Activity_High      50000 non-null  bool
#  37  Physical_Activity_Low       50000 non-null  bool
#  38  Physical_Activity_Moderate  50000 non-null  bool
#  39  Education_Level_Higher      50000 non-null  bool
#  40  Education_Level_Primary     50000 non-null  bool
#  41  Education_Level_Secondary   50000 non-null  bool
#  42  Marital_Status_Divorced     50000 non-null  bool
#  43  Marital_Status_Married      50000 non-null  bool
#  44  Marital_Status_Single       50000 non-null  bool
#  45  Marital_Status_Widowed      50000 non-null  bool
#  46  Urban_Rural_Rural           50000 non-null  bool
# dtypes: bool(37), float64(5), int64(5)
# memory usage: 5.6 MB

# %%
corr_matrix=df.corr()
corr_matrix["Heart_Attack"].sort_values()
# Out:
# Blood_Pressure               -0.010560
# Urban_Rural_Rural            -0.008209
# Physical_Activity_Low        -0.006333
# Medication                   -0.006285
# Marital_Status_Married       -0.005854
# Stress_Level                 -0.005845
# Region_Urban                 -0.005028
# Education_Level_Higher       -0.004850
# Diabetes                     -0.004789
# Income_Level_Low             -0.004730
# Heart_Disease_History        -0.004472
# Diet_Unhealthy               -0.004111
# Health_Awareness             -0.003775
# Occupation_Unemployed        -0.003706
# Cholesterol                  -0.003397
# Occupation_Retired           -0.002509
# Heart_Rate                   -0.002241
# Obesity                      -0.000750
# Exercise_Level_Low           -0.000684
# Mental_Health                -0.000619
# BMI                          -0.000526
# Education_Level_Secondary    -0.000497
# Exercise_Level_Moderate       0.000230
# Gender_Female                 0.000235
# Family_History                0.000322
# Diet_Healthy                  0.000434
# Exercise_Level_High           0.000499
# Marital_Status_Widowed        0.000527
# Age                           0.000841
# Income_Level_Middle           0.000970
# Occupation_Employed           0.000990
# Region_Rural                  0.001634
# Daily_Water_Intake            0.001709
# Gender_Male                   0.001828
# Angina                        0.002055
# Marital_Status_Divorced       0.002224
# Physical_Activity_Moderate    0.002450
# Sleep_Hours                   0.003141
# Diet_Mixed                    0.003637
# Physical_Activity_High        0.004212
# Occupation_Student            0.004304
# Region_Suburban               0.004412
# Income_Level_High             0.004579
# Marital_Status_Single         0.004758
# Education_Level_Primary       0.005380
# Smoking                       0.010113
# Heart_Attack                  1.000000
# Name: Heart_Attack, dtype: float64

# %%
x = df.drop("Heart_Attack", axis=1)
y = df["Heart_Attack"]

# %%
cc = ClusterCentroids(random_state=42)
with parallel_backend('threading', n_jobs=-1):
    x_resampled, y_resampled = cc.fit_resample(x, y)

# %%
x_resampled.shape, y_resampled.shape
# Out:
# ((11762, 46), (11762,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, random_state=42, test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((9409, 46), (2353, 46), (9409,), (2353,))

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8382 - loss: 0.4515
# Epoch 2/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9692 - loss: 0.1074
# Epoch 3/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0933
# Epoch 4/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9788 - loss: 0.0822
# Epoch 5/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0806
# Epoch 6/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0797
# Epoch 7/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0822
# Epoch 8/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0709
# Epoch 9/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.0567
# Epoch 10/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9831 - loss: 0.0659
# Epoch 11/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9839 - loss: 0.0597
# Epoch 12/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.0564
# Epoch 13/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9839 - loss: 0.0578
# Epoch 14/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0549
# Epoch 15/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0421
# Epoch 16/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0374
# Epoch 17/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9861 - loss: 0.0467
# Epoch 18/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9860 - loss: 0.0450
# Epoch 19/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9894 - loss: 0.0350
# Epoch 20/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9874 - loss: 0.0435
# Epoch 21/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9905 - loss: 0.0314
# Epoch 22/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0335
# Epoch 23/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9897 - loss: 0.0365
# Epoch 24/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0286
# Epoch 25/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0275
# Epoch 26/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0296
# Epoch 27/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0302
# Epoch 28/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9911 - loss: 0.0299
# Epoch 29/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9919 - loss: 0.0249
# Epoch 30/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0264
# Epoch 31/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9893 - loss: 0.0311
# Epoch 32/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0284
# Epoch 33/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9909 - loss: 0.0266
# Epoch 34/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9906 - loss: 0.0248
# Epoch 35/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9921 - loss: 0.0231
# Epoch 36/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0263
# Epoch 37/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9915 - loss: 0.0237
# Epoch 38/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9921 - loss: 0.0235
# Epoch 39/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9914 - loss: 0.0228
# Epoch 40/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9923 - loss: 0.0223
# Epoch 41/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9907 - loss: 0.0257
# Epoch 42/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9936 - loss: 0.0191
# Epoch 43/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0186
# Epoch 44/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.0236
# Epoch 45/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9941 - loss: 0.0221
# Epoch 46/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0208
# Epoch 47/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9927 - loss: 0.0221
# Epoch 48/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9931 - loss: 0.0228
# Epoch 49/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0188
# Epoch 50/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9928 - loss: 0.0223
# Epoch 51/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9934 - loss: 0.0185
# Epoch 52/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9941 - loss: 0.0172
# Epoch 53/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9938 - loss: 0.0180
# Epoch 54/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0169
# Epoch 55/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9937 - loss: 0.0165
# Epoch 56/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0193
# Epoch 57/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9950 - loss: 0.0146
# Epoch 58/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9927 - loss: 0.0197
# Epoch 59/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0175
# Epoch 60/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9952 - loss: 0.0152
# Epoch 61/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0216
# Epoch 62/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0181
# Epoch 63/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0153
# Epoch 64/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9933 - loss: 0.0211
# Epoch 65/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0140
# Epoch 66/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9949 - loss: 0.0164
# Epoch 67/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0193
# Epoch 68/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9939 - loss: 0.0153
# Epoch 69/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9952 - loss: 0.0141
# Epoch 70/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9941 - loss: 0.0176
# Epoch 71/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9954 - loss: 0.0131
# Epoch 72/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9947 - loss: 0.0170
# Epoch 73/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0162
# Epoch 74/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9948 - loss: 0.0140
# Epoch 75/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0155
# Epoch 76/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0156
# Epoch 77/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9953 - loss: 0.0146
# Epoch 78/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0149
# Epoch 79/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0135
# Epoch 80/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0161
# Epoch 81/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0158
# Epoch 82/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9955 - loss: 0.0131
# Epoch 83/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9953 - loss: 0.0139
# Epoch 84/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0128
# Epoch 85/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9948 - loss: 0.0148
# Epoch 86/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9949 - loss: 0.0135
# Epoch 87/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0116
# Epoch 88/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9953 - loss: 0.0130
# Epoch 89/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9948 - loss: 0.0119
# Epoch 90/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9945 - loss: 0.0129
# Epoch 91/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0125
# Epoch 92/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9950 - loss: 0.0156
# Epoch 93/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9932 - loss: 0.0145
# Epoch 94/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0135
# Epoch 95/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0131
# Epoch 96/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0149
# Epoch 97/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0167
# Epoch 98/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0139
# Epoch 99/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0105
# Epoch 100/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9956 - loss: 0.0115
# Epoch 101/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9955 - loss: 0.0112
# Epoch 102/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9944 - loss: 0.0151
# Epoch 103/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9940 - loss: 0.0148
# Epoch 104/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9942 - loss: 0.0148
# Epoch 105/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9951 - loss: 0.0131
# Epoch 106/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9933 - loss: 0.0189
# Epoch 107/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9948 - loss: 0.0134
# Epoch 108/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9959 - loss: 0.0128
# Epoch 109/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0125
# Epoch 110/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9957 - loss: 0.0127
# Epoch 111/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0112
# Epoch 112/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9961 - loss: 0.0113
# Epoch 113/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9951 - loss: 0.0133
# Epoch 114/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9950 - loss: 0.0119
# Epoch 115/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9960 - loss: 0.0116
# Epoch 116/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9959 - loss: 0.0109
# Epoch 117/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0152
# Epoch 118/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0101
# Epoch 119/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0089
# Epoch 120/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0110
# Epoch 121/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0115
# Epoch 122/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0129
# Epoch 123/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9973 - loss: 0.0101
# Epoch 124/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0100
# Epoch 125/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9959 - loss: 0.0125
# Epoch 126/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9960 - loss: 0.0106
# Epoch 127/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9972 - loss: 0.0092
# Epoch 128/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0124
# Epoch 129/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0092
# Epoch 130/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0106
# Epoch 131/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0118
# Epoch 132/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0143
# Epoch 133/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9952 - loss: 0.0127
# Epoch 134/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9942 - loss: 0.0159
# Epoch 135/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0111
# Epoch 136/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0121
# Epoch 137/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0116
# Epoch 138/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0107
# Epoch 139/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0115
# Epoch 140/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9968 - loss: 0.0096
# Epoch 141/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9961 - loss: 0.0108
# Epoch 142/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0107
# Epoch 143/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9972 - loss: 0.0096
# Epoch 144/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0102
# Epoch 145/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9966 - loss: 0.0104
# Epoch 146/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0079
# Epoch 147/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0084
# Epoch 148/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9956 - loss: 0.0120
# Epoch 149/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0090
# Epoch 150/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0099
# Epoch 151/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9974 - loss: 0.0084
# Epoch 152/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0106
# Epoch 153/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0090
# Epoch 154/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9972 - loss: 0.0095
# Epoch 155/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0101
# Epoch 156/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9969 - loss: 0.0108
# Epoch 157/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9950 - loss: 0.0149
# Epoch 158/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0094
# Epoch 159/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0105
# Epoch 160/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0097
# Epoch 161/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0118
# Epoch 162/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9969 - loss: 0.0079
# Epoch 163/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9963 - loss: 0.0106
# Epoch 164/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0124
# Epoch 165/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0109
# Epoch 166/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0112
# Epoch 167/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0093
# Epoch 168/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0087
# Epoch 169/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9981 - loss: 0.0087
# Epoch 170/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9976 - loss: 0.0081
# Epoch 171/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9974 - loss: 0.0090
# Epoch 172/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0099
# Epoch 173/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0072
# Epoch 174/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9979 - loss: 0.0074
# Epoch 175/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0102
# Epoch 176/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9974 - loss: 0.0112
# Epoch 177/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0102
# Epoch 178/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0097
# Epoch 179/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9980 - loss: 0.0067
# Epoch 180/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0120
# Epoch 181/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0121
# Epoch 182/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0102
# Epoch 183/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9975 - loss: 0.0097
# Epoch 184/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9982 - loss: 0.0064
# Epoch 185/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0114
# Epoch 186/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9975 - loss: 0.0075
# Epoch 187/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0081
# Epoch 188/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0088
# Epoch 189/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0099
# Epoch 190/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0091
# Epoch 191/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0081
# Epoch 192/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0074
# Epoch 193/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9985 - loss: 0.0069
# Epoch 194/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9981 - loss: 0.0073
# Epoch 195/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9975 - loss: 0.0103
# Epoch 196/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9978 - loss: 0.0088
# Epoch 197/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9979 - loss: 0.0085
# Epoch 198/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9977 - loss: 0.0078
# Epoch 199/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0084
# Epoch 200/200
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0068
